# %%
#untiy catalog object names
catalog_name = 'formula1_incr'
storage_account = 'azureprostorageaccext'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'
control_schema = 'control'

# %%
loading_folder_path = '/Volumes/formula1_incr/landing/files'
