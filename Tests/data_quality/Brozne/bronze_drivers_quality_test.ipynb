# %% [markdown]
# test to check data loaded correctly

# %%
def test_drivers_not_empty():
    df = spark.table("formula1_incr.bronze.drivers")
    assert df.count() > 0

# %%
def test_driverid_not_null():
    df = spark.table("formula1_incr.bronze.drivers")
    assert df.filter("driverId IS NULL").count() == 0
