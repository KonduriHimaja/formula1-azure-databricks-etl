# %%
def test_constructors_not_empty():
    df = spark.table("formula1_incr.silver.constructors")
    assert df.count() > 0

# %%
def test_constructors_not_empty():
    df = spark.table("formula1_incr.silver.constructors")
    assert df.filter("constructor_name IS NULL").count() == 0
