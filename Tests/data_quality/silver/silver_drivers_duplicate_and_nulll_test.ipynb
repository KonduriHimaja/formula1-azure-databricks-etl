# %%
def test_drivers_not_empty():
    df = spark.table("formula1_incr.silver.drivers")
    assert df.count() > 0

# %%
def test_driver_name_not_null():
    df = spark.table("formula1_incr.silver.drivers")
    assert df.filter("driver_name IS NULL").count() == 0
